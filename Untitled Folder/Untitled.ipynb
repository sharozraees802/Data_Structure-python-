# %%
import numpy as np
val=int(input("enter no "))
a=0
b=1
count=0
while b<val:
    #print(b)
    a,b=b,a+b
    count+=1
f=np.array([0 for i in range(count)])
f[0]=0
f[1]=1

print(" ")

print("==========================")


for i in range(2,count,1):
    f[i]=f[i-1]+f[i-2]
#     print(f[i],end=" ")
    
    
    
print(" ")

print("==========================")    

for i in range(2,count,1):
    f[i]=f[i-1]+f[i-2]
      
    if i in range(2,f[i]):
        if f[i]%i==0:
            break
    else:
        print(f[i],end=" ")
                
print(" ")

print("===========index===============")               
index=int(input("enter index where you want to add "))
value =int(input(f"enter value of index{index}: "))
temp=np.array([0 for i in range((len(f)+1))])
j=0
for i in range(len(temp)):
    if(i==index):
        temp[i]=value
    else:
        temp[i]=f[j]
        j+=1
        
f=temp
for i in range(len(f)):
    print(f[i],end=" ")
    
print()    
for i in range(len(f)):    
    if j in range(1,f[i]):
        if f[i]%j==0:
            break
    else:
        print(f[i],end=" ")
    


print()
print("=============delete=================")
index=int(input("enter element index that u want to delete"))
temp=np.array([0 for i in range(len(f)-1)])

j=0
for i in range(len(f)):
    if i == index:
        continue
    else:
        temp[j]=f[i]
        j+=1
f=temp
        
for i in range(len(f)):
     print(f[i],end=" ")
# Out:
# enter no 55
#
# ...
#
# ...
# 1 2 3 5
# ===========index===============
